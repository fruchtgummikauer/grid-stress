# %% [markdown]
# # PM Session 2 — GridStress
# **Hari Raj Singh · Team PowerNap · 24 September 2026**
#
# ## From exploratory patterns to a fair forecast comparison
# A high-level, figure-led review of feature families, baseline regression and classification,
# evaluation, business hypotheses and the next evidence milestones.
#
# **For this session:** agree the forecasting contract, review the recorded research evidence,
# and decide which missing checks must be completed before the next model comparison.
#
# **Evidence status:** figures below are saved outputs from the supplied notebooks. This PM
# notebook does not rerun those notebooks, download data or fit a model. The requested forecast
# origin is **D−1 18:00 Europe/Berlin**. The main saved evaluation source still declares noon;
# its recorded results are **not relabelled as a verified 18:00 run**. Observed hourly evidence
# is not native 15-minute evidence. Missing updates are marked **ADD** or **REPLACE**.
#
# All figures are embedded in this file; no local research-data path is needed to view it.

# %% [markdown]
# ## Session 1 → Session 2
# Session 1 framed a four-week project, an hourly EDA, the SMARD grid source and the reBAP
# cost source. It left the risk label, success metrics and feature review as decisions to resolve.
#
# | Session 2 topic | What we can review now | What still needs evidence |
# |---|---|---|
# | Forecast contract | Next complete Berlin-local day; requested 18:00 origin | Matching feature and evaluation rerun |
# | Feature engineering | Fourteen declared families and saved explanatory figures | Dedicated evidence for marked gaps and origin/vintage checks |
# | Model testing | Saved chronological baseline comparisons | Consistent 18:00 comparison on identical future targets |
# | Product value | Next-day profile and stress-risk service hypothesis | Decision-specific cost exposure and user validation |
#
# **PM questions:** Is the scope achievable? Which feature families deserve priority?
# What evidence is required before calling the MVP useful?
#
# *Source: `PM-Session1.ipynb`, markdown cells 0–2; the new evidence is from the notebooks listed at the end.*

# %% [markdown]
# ## What is known before forecasting tomorrow?
# One forecast is issued at **18:00 on D−1** for the complete day D. Use only qualified inputs
# available at the cutoff. The clock below is a specification, not a model-performance result.
#
# **REPLACE ORIGIN:** recompute origin-dependent features and evaluations under this contract;
# preserve publication timing, historical vintages and local-day/DST semantics.

# %% [markdown]
# ![Requested 18:00 forecast clock — specification only.](attachment:forecast_clock.png)
#
# *Requested 18:00 forecast clock — specification only.*

# %% [markdown]
# ## What part of 2019–2026 is observed?
# The saved coverage map reports the actual source support separately from the requested
# calendar envelope. The final year is partial. Blank future months are not zero observations.
#
# This is an hourly saved-evidence view; the chart’s source endpoint is retained.

# %% [markdown]
# ![Joint coverage of the saved source extract; final year partial.](attachment:coverage.png)
#
# *Joint coverage of the saved source extract; final year partial.*

# %% [markdown]
# ## How are future days kept separate from training?
# The recorded research uses seven chronological development folds and an eight-day gap.
# Each scored profile belongs to one complete target local day.
#
# | Fold | Training through | Validation start | Validation end |
# |---|---|---|---|
# | F1 | 2021-06-30 | 2021-07-09 | 2021-12-31 |
# | F2 | 2021-12-31 | 2022-01-09 | 2022-06-30 |
# | F3 | 2022-06-30 | 2022-07-09 | 2022-12-31 |
# | F4 | 2022-12-31 | 2023-01-09 | 2023-06-30 |
# | F5 | 2023-06-30 | 2023-07-09 | 2023-12-31 |
# | F6 | 2023-12-31 | 2024-01-09 | 2024-06-30 |
# | F7 | 2024-06-30 | 2024-07-09 | 2024-12-31 |
#
# **Next comparison, not yet an implemented result:** expanding history versus rolling
# 24/36/48-month history, with adaptive memory chosen only from earlier inner validation.
# Outer future targets must remain the same for a fair comparison.
#
# **UPDATE SPLIT:** add the executed inner/outer selection receipt and actual evaluation
# boundary. Already inspected history cannot be described as an untouched final test.
#
# *Source: feature-engineering notebook, `fold_specification`; presentation update map, slide 5.*

# %% [markdown]
# ## Feature-family map
# A family’s presence in the registry does not establish predictive benefit or historical availability.
# The PM discussion is **pattern → candidate → timing/provenance → forward evidence → decision**.
#
# | ID | Family | What it represents |
# |---|---|---|
# | F0 | Calendar | Hour, weekday, day of year, month, weekend and holiday; DST metadata kept separate. |
# | F1 | Temporal geometry | Paired cyclic coordinates for daily, weekly and annual phase; daily second harmonic. |
# | F2 | Safe persistence | D−2 and earlier weekly matches, weekly median and median absolute deviation. |
# | F3 | Origin state | Latest eligible residual load, load, VRE and one-hour residual change. |
# | F4 | Rolling state | 24/72/168-hour mean and standard deviation; history support indicator. |
# | F5 | Physical history | D−2 and D−7 local-profile matches for load, onshore/offshore wind and solar. |
# | F6 | D−2 shape | Centred D−2 residual profile and the corresponding one-hour change. |
# | S0 | Scheduled events | Christmas/New Year, bridge opportunities, long weekends and holiday distances. |
# | S1 | Extra signal basis | Daily third-harmonic and weekly second-harmonic sine/cosine pairs. |
# | S2 | Spectral state | Trailing-window energy shares, amplitudes, power ratio, reconstruction error and entropy. |
# | F10 | Selected interactions | Declared interactions between eligible clock, persistence and state inputs. |
# | F9 | Origin control state | Ramps, slope, VRE share, ramp variability, stress memory and state indicators. |
# | S4 | Context-modulated harmonics | Six daily terms × four weekly/annual context terms = 24 products. |
# | S3 | Intervention adaptation | Declared event steps, time-since-event variables and event interactions. |

# %% [markdown]
# ### F0 — Calendar: does residual load repeat with the local calendar?
# Weekday and seasonal patterns motivate calendar representations. The heatmaps do not prove
# an effect for every holiday or DST variable. DST identity and day length remain time-integrity
# metadata even when they are not useful model predictors.

# %% [markdown]
# ![Saved observed calendar profiles. Descriptive evidence, not feature-selection proof.](attachment:calendar_patterns.png)
#
# *Saved observed calendar profiles. Descriptive evidence, not feature-selection proof.*

# %% [markdown]
# ### F1 — Temporal geometry: can a cyclic clock represent daily shape?
# The real mean profile and harmonic reconstructions explain the daily representation.
# The third-harmonic comparison is explanatory; standalone H3 terms belong to S1.
#
# **ADD F1:** separate weekday/annual support and forward evidence as needed.
# This fitted mean day is not a next-day prediction.

# %% [markdown]
# ![Observed mean daily profile with fitted harmonic reconstructions.](attachment:harmonic_shape.png)
#
# *Observed mean daily profile with fitted harmonic reconstructions.*

# %% [markdown]
# ### F2 — Safe persistence: do earlier same-clock values provide a reference?
# Candidate predictors: D−2, D−7 and D−14 residual-load matches, plus a median and MAD derived
# from four previous weekly matches. ACF/PACF motivates lag investigation but does not prove
# availability at the forecast origin.
#
# **ADD F2:** previous-four-weeks comparison with median, MAD and support. Distinguish local-day
# matching from fixed elapsed hours around DST. MAD is historical dispersion, not a forecast interval.

# %% [markdown]
# ![Saved training-only ACF/PACF diagnostic; recheck the exact adjustment and origin contract on refresh.](attachment:persistence_memory.png)
#
# *Saved training-only ACF/PACF diagnostic; recheck the exact adjustment and origin contract on refresh.*

# %% [markdown]
# ### F3 — Origin state: does the latest eligible snapshot help describe tomorrow?
# `origin_residual_load_mw` · `origin_load_mw` · `origin_vre_mw` · `origin_ramp_1h_mw`
#
# Use an observation available by issue time, not target-day actuals. Check the accounting
# redundancy between residual load, load and VRE.

# %% [markdown]
# > **ADD FIGURE · F3**
# >
# > Origin-state variables versus matched next-day outcomes, with one record per origin for daily-outcome comparisons. Presentation slide 9.
# >
# > Reserved for the updated notebook; no substitute result is presented.

# %% [markdown]
# ### F4 — Rolling state: does recent level and variability carry into tomorrow?
# The family contains 24/72/168-hour residual-load means and standard deviations.
# `history_support_count` counts four available historical inputs; it is not a rolling-window sample count.

# %% [markdown]
# > **ADD FIGURE · F4**
# >
# > Dedicated rolling-mean and rolling-standard-deviation evidence against next-day level/spread, including missingness and support. Presentation slide 10.
# >
# > Reserved for the updated notebook; no substitute result is presented.

# %% [markdown]
# ### F5 — Physical history: which historical inputs retain information?
# The family uses past load, onshore wind, offshore wind and solar. The displayed diagnostic
# covers load and aggregate VRE, not separate evidence for all eight component-lag features.
#
# **ADD F5:** four-component evidence at the actual eligible D−2/D−7 matching.
# Association with residual load is partly mechanical; it is not causal evidence.

# %% [markdown]
# ![Calendar-adjusted lagged association and coherence from the saved research diagnostic.](attachment:physical_history.png)
#
# *Calendar-adjusted lagged association and coherence from the saved research diagnostic.*

# %% [markdown]
# ### F6 — D−2 shape: does an earlier day retain useful intraday shape?
# `shape_d2_centered_mw` · `shape_d2_ramp_1h_mw`
#
# Compare the shape around the earlier day’s mean and its one-hour changes.
# A realised target-day mean used for comparison must not enter predictors.

# %% [markdown]
# > **ADD FIGURE · F6**
# >
# > D−2 centred shape and ramp versus target-day shape/ramp across many eligible days. State the example-selection rule. Presentation slide 12.
# >
# > Reserved for the updated notebook; no substitute result is presented.

# %% [markdown]
# ### S0 — Scheduled events: do special days differ from comparable ordinary days?
# The saved holiday profile provides observed context. It does not establish all Christmas,
# New Year, bridge-day, long-weekend and holiday-distance features.
#
# **ADD S0:** matched special-day profiles with counts, repeated-year support and holiday scope.

# %% [markdown]
# ![Saved national-holiday grid-load profiles; event support and matching still need review.](attachment:scheduled_events.png)
#
# *Saved national-holiday grid-load profiles; event support and matching still need review.*

# %% [markdown]
# ### S1 — Extra signal basis: is there structure beyond the basic clock?
# Candidates add daily H3 and weekly H2 sine/cosine pairs. The saved spectrum and fitted
# amplitudes explain the distinction between discovery and reconstruction.
#
# **ADD S1:** isolate the 8-hour and 84-hour terms and assess incremental forward value.

# %% [markdown]
# ![Past-window spectral and harmonic diagnostic; no next-day forecast is implied.](attachment:extra_harmonics.png)
#
# *Past-window spectral and harmonic diagnostic; no next-day forecast is implied.*

# %% [markdown]
# ### S2 — Spectral state: does the strength of the rhythms change?
# Trailing 28-day windows produce origin-specific candidates: band energies, amplitudes,
# power ratio, reconstruction error and entropy.
#
# **REPLACE S2:** rebuild eligible windows at 18:00 and retain missing-window and vintage checks.
# A past-window projection is not a forecast.

# %% [markdown]
# ![Saved trailing-window spectral state. Origin-dependent results require the declared refresh.](attachment:spectral_state.png)
#
# *Saved trailing-window spectral state. Origin-dependent results require the declared refresh.*

# %% [markdown]
# ### F10 — Selected interactions: does the relationship depend on context?
# Declared interactions include hour × season, origin VRE × daily phase, weekly reference ×
# weekend and spectral-amplitude × calendar terms. Every parent must be origin-eligible.

# %% [markdown]
# > **ADD FIGURE · F10**
# >
# > Conditional response for a declared interaction, main-effect comparison and bin support; check overlap with S4. Presentation slide 16.
# >
# > Reserved for the updated notebook; no substitute result is presented.

# %% [markdown]
# ### F9 — Origin control state: do recent motion and instability change risk?
# Ramps, six-hour slope, VRE share, ramp variability, stress memory and state indicators
# describe the latest sampled condition. Their variation alone is not evidence of next-day predictive value.
#
# **REPLACE F9:** add 18:00 state-to-next-day-risk evidence with support and past-fitted thresholds.

# %% [markdown]
# ![Saved origin-control traces. Slope, ramp variability and stress memory belong to F9.](attachment:origin_control.png)
#
# *Saved origin-control traces. Slope, ramp variability and stress memory belong to F9.*

# %% [markdown]
# ### S4 — Context-modulated harmonics: does daily shape change with context?
# Six daily sine/cosine terms are crossed with four weekday/annual context terms to form
# 24 declared products. The calendar heatmaps above motivate this hypothesis, but do not validate
# each product independently.
#
# **ADD S4:** joint weekday-by-season evidence, redundancy checks and matched forward ablation.
# Presentation slide 18 retains the compact construction; all exact names belong in the feature register.

# %% [markdown]
# ### S3 — Intervention adaptation: does behaviour differ around declared disruptions?
# Event steps, time-since-event clocks and interactions are adaptation candidates.
# Historical reporting-period differences are not causal evidence.
#
# **ADD S3:** calendar-adjusted, availability-gated observations with the documented event ledger.

# %% [markdown]
# ![Observed reporting-period comparison; intervention/adaptation research only.](attachment:intervention_context.png)
#
# *Observed reporting-period comparison; intervention/adaptation research only.*

# %% [markdown]
# ## Baseline classification — can we trust stress probabilities?
# **C0:** training prevalence. **C1:** risk derived from the regression forecast.
# **C2:** logistic regression for broad any-stress. Separate upper-tail and lower/negative-tail
# heads address different events and must not be merged into the same task.
#
# The saved reliability view asks whether predicted probabilities agree with observed event rates.
# Ranking quality alone does not answer calibration or acceptable alert burden.
#
# **REPLACE C:** matched 18:00 out-of-fold probabilities, prevalence, sample support and
# thresholds selected on earlier data.

# %% [markdown]
# ![Saved broad any-stress enrichment and reliability evidence; not a new 18:00 evaluation.](attachment:classification.png)
#
# *Saved broad any-stress enrichment and reliability evidence; not a new 18:00 evaluation.*

# %% [markdown]
# ## Baseline regression — do engineered models improve on internal references?
# **B0:** calendar climatology. **B1:** safe weekly persistence.
# **B3:** engineered Ridge. **B4:** shallow histogram gradient boosting.
# B2 and B5 remain dependent on qualified historical official-forecast vintages.
#
# The following chart is the recorded research comparison. Preserve the distinctions between
# per-fold errors, paired fold differences and the daily-error distribution.
#
# **REPLACE R:** a consistent 18:00 comparison on identical complete target-day keys and folds.

# %% [markdown]
# ![Saved baseline regression results: fold error comparison and B3 daily-error distribution.](attachment:regression.png)
#
# *Saved baseline regression results: fold error comparison and B3 daily-error distribution.*

# %% [markdown]
# ## Metrics and evaluation — what does an average score hide?
# **Magnitude:** MAE, RMSE and bias. **Daily shape:** profile, ramp and peak/trough timing.
# **Tails and probabilities:** tail errors, support, recall, average precision and Brier score.
# These measures answer different questions; do not combine their units into a single number.
#
# The saved failure view deliberately includes a difficult B3 out-of-fold day. It is a diagnostic,
# not a typical-day or operational demonstration.
#
# **REPLACE M:** matched 18:00 evaluation, explicit aggregation, tail support and computed
# uncertainty. Use the same targets when comparing models.

# %% [markdown]
# ![Saved out-of-fold error diagnostics and a deliberately selected difficult B3 day.](attachment:evaluation.png)
#
# *Saved out-of-fold error diagnostics and a deliberately selected difficult B3 day.*

# %% [markdown]
# ## Business hypothesis — what planning decision could this support?
# | Candidate user | Service hypothesis | Value to test |
# |---|---|---|
# | Grid/control-area planners and energy-system analysts | A next-day residual-load profile with separate stress probabilities and a transparent scorecard | Earlier visibility of unusual levels, ramps and uncertainty; improved preparation under an explicit decision rule |
#
# Residual-load stress is a research proxy, not a demonstrated congestion or grid-security alarm.
#
# **ADD VALUE:** join the appropriate reBAP/settlement exposure data, preserve MW/MWh distinctions
# and test one decision-specific cost comparison. Savings, customer adoption, pricing and
# willingness to pay have not been established by the supplied results.

# %% [markdown]
# ## Future goals and discussion
# **First:** verify the 18:00 information set, cadence, publication timing and historical vintages.
# **Then:** compare legal training memories and model challengers on the same future targets.
# ARIMA, SARIMA and boosted-tree extensions remain proposals until evaluated.
# **Finally:** test a concrete user decision and cost exposure rather than equating model accuracy with business value.
#
# ### Decisions to make in the PM session
# 1. Which decision is the minimum viable product meant to support?
# 2. Which missing family figures and origin/vintage checks are essential before the next comparison?
# 3. What false-alert burden, forecast error and evidence threshold would make the result useful?
#
# These continue Session 1’s scope, risk-label, feature-selection and success-metric questions.
